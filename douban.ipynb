# %% [markdown]
# - 调用库

# %%
# pyecharts文档  https://pyecharts.org/#/
# pyecharts实例  https://gallery.pyecharts.org/#/
import pandas as pd
import numpy as np #用于计算
from sqlalchemy import create_engine
import mysql.connector
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.charts import Bar
from pyecharts.charts import Pie
from pyecharts.charts import Line
from pyecharts.charts import Funnel
from pyecharts.options.global_options import ThemeType
import os
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_NOTEBOOK

# %% [markdown]
# - 建立连接

# %%
engine = create_engine("mysql+mysqlconnector://root:root@localhost:3306/douban?charset=utf8")
conn = engine.connect()

df = pd.read_sql("douban_top250", conn)
conn.close()

# %% [markdown]
# ## 视角一

# %%
def country(situa): # 获取此国家的制品电影数
    death = df['area'].str.contains(situa)
    Situa = df.loc[death]
    return len(Situa)
    
Country_value = [country('中国'), country('美国'), country('英国'), country('法国'), country('意大利'), country('日本'), \
    country('新西兰'), country('韩国'), country('瑞士'), country('印度'), country('波兰'), country('澳大利亚'), country('墨西哥'), \
        country('卡塔尔'), country('黎巴嫩'), country('爱尔兰'), country('加拿大'), country('德国')]
Country_attr = ['China', 'United States', 'United Kingdom', 'France', 'Italy', 'Japan', 'New Zealand', 'Korea',\
     'Swizetland', 'India', 'Poland', 'Australia', 'Mexico', 'Qatar', 'Lebanon', 'Ireland', 'Canada', 'Germany']

# %%
# Map - Map_world
# https://gallery.pyecharts.org/#/Map/map_world
value = Country_value
attr = Country_attr
data = []
for index in range(len(attr)):
    city_ionfo=[attr[index],value[index]]
    data.append(city_ionfo)
m = (
    Map()
    .add("世界地图",data, "world")
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="top250电影制片国家"),
        visualmap_opts=opts.VisualMapOpts(max_=80),
 
    )
    # .render(path='热力图.html')
)
 
# os.system("热力图.html")
m.render_notebook() # notebook中运行
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="75e1100f0a9049e99e37b0e569a4d935" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_75e1100f0a9049e99e37b0e569a4d935 = echarts.init(
#                     document.getElementById('75e1100f0a9049e99e37b0e569a4d935'), 'white', {renderer: 'canvas'});
#                 var option_75e1100f0a9049e99e37b0e569a4d935 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u4e16\u754c\u5730\u56fe",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "China",
#                     "value": 46
#                 },
#                 {
#                     "name": "United States",
#                     "value": 140
#                 },
#                 {
#                     "name": "United Kingdom",
#                     "value": 35
#                 },
#                 {
#                     "name": "France",
#                     "value": 20
#                 },
#                 {
#                     "name": "Italy",
#                     "value": 10
#                 },
#                 {
#                     "name": "Japan",
#                     "value": 35
#                 },
#                 {
#                     "name": "New Zealand",
#                     "value": 3
#                 },
#                 {
#                     "name": "Korea",
#                     "value": 12
#                 },
#                 {
#                     "name": "Swizetland",
#                     "value": 4
#                 },
#                 {
#                     "name": "India",
#                     "value": 3
#                 },
#                 {
#                     "name": "Poland",
#                     "value": 1
#                 },
#                 {
#                     "name": "Australia",
#                     "value": 5
#                 },
#                 {
#                     "name": "Mexico",
#                     "value": 1
#                 },
#                 {
#                     "name": "Qatar",
#                     "value": 1
#                 },
#                 {
#                     "name": "Lebanon",
#                     "value": 1
#                 },
#                 {
#                     "name": "Ireland",
#                     "value": 1
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 9
#                 },
#                 {
#                     "name": "Germany",
#                     "value": 16
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {},
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e16\u754c\u5730\u56fe"
#             ],
#             "selected": {
#                 "\u4e16\u754c\u5730\u56fe": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "top250\u7535\u5f71\u5236\u7247\u56fd\u5bb6",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 80,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_75e1100f0a9049e99e37b0e569a4d935.setOption(option_75e1100f0a9049e99e37b0e569a4d935);
#         });
#     </script>

# %%
# Bar - Bar_base
# https://gallery.pyecharts.org/#/Bar/bar_base
x_choose=Country_attr
y_values=Country_value
b= (
    Bar(
        init_opts=opts.InitOpts(
            theme=ThemeType.DARK,
        )
    )
    .add_xaxis(x_choose)
    .add_yaxis("电影数量", y_values,)
    .set_global_opts(
        
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=35)),
        title_opts=opts.TitleOpts(title="top250电影制片国家对比"),
        # brush_opts=opts.BrushOpts(),

    )
    # .render(path='柱状图.html')
)
b.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b66230a6ea2b4e79bd82b7c76760b17a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b66230a6ea2b4e79bd82b7c76760b17a = echarts.init(
#                     document.getElementById('b66230a6ea2b4e79bd82b7c76760b17a'), 'dark', {renderer: 'canvas'});
#                 var option_b66230a6ea2b4e79bd82b7c76760b17a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7535\u5f71\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 46,
#                 140,
#                 35,
#                 20,
#                 10,
#                 35,
#                 3,
#                 12,
#                 4,
#                 3,
#                 1,
#                 5,
#                 1,
#                 1,
#                 1,
#                 1,
#                 9,
#                 16
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7535\u5f71\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u7535\u5f71\u6570\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 35,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "China",
#                 "United States",
#                 "United Kingdom",
#                 "France",
#                 "Italy",
#                 "Japan",
#                 "New Zealand",
#                 "Korea",
#                 "Swizetland",
#                 "India",
#                 "Poland",
#                 "Australia",
#                 "Mexico",
#                 "Qatar",
#                 "Lebanon",
#                 "Ireland",
#                 "Canada",
#                 "Germany"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "top250\u7535\u5f71\u5236\u7247\u56fd\u5bb6\u5bf9\u6bd4",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_b66230a6ea2b4e79bd82b7c76760b17a.setOption(option_b66230a6ea2b4e79bd82b7c76760b17a);
#         });
#     </script>

# %%
# Pie - Pie_rich_label
# https://gallery.pyecharts.org/#/Pie/pie_rich_label

sortedData = sorted(data, key=lambda st:st[1], reverse=True)

p = (
    Pie()
    .add(
        "",
        sortedData,
        radius=["30%", "45%"],
        label_opts=opts.LabelOpts(
            position="outside",
            formatter=" {b|{b}: }{c}  {per|{d}%} ",
            background_color="#eee",
            border_color="#aaa",
            border_width=1,
            border_radius=4,
            rich={
                "a": {"color": "#999", "lineHeight": 22, "align": "center"},
                "abg": {
                    "backgroundColor": "#e3e3e3",
                    "width": "100%",
                    "align": "right",
                    "height": 20,
                    "borderRadius": [4, 4, 0, 0],
                },
                "hr": {
                    "borderColor": "#aaa",
                    "width": "100%",
                    "borderWidth": 0.5,
                    "height": 0,
                },
                "b": {"fontSize": 10, "lineHeight": 18},
                "per": {
                    "color": "#eee",
                    "backgroundColor": "#334455",
                    "padding": [2, 4],
                    "borderRadius": 2,
                },
            },
        ),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="top250电影制片国家比重"),
        legend_opts=opts.LegendOpts(is_show=False)
    )
)
p.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="768c3ab23358468088668b5e7d440cf7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_768c3ab23358468088668b5e7d440cf7 = echarts.init(
#                     document.getElementById('768c3ab23358468088668b5e7d440cf7'), 'white', {renderer: 'canvas'});
#                 var option_768c3ab23358468088668b5e7d440cf7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "United States",
#                     "value": 140
#                 },
#                 {
#                     "name": "China",
#                     "value": 46
#                 },
#                 {
#                     "name": "United Kingdom",
#                     "value": 35
#                 },
#                 {
#                     "name": "Japan",
#                     "value": 35
#                 },
#                 {
#                     "name": "France",
#                     "value": 20
#                 },
#                 {
#                     "name": "Germany",
#                     "value": 16
#                 },
#                 {
#                     "name": "Korea",
#                     "value": 12
#                 },
#                 {
#                     "name": "Italy",
#                     "value": 10
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 9
#                 },
#                 {
#                     "name": "Australia",
#                     "value": 5
#                 },
#                 {
#                     "name": "Swizetland",
#                     "value": 4
#                 },
#                 {
#                     "name": "New Zealand",
#                     "value": 3
#                 },
#                 {
#                     "name": "India",
#                     "value": 3
#                 },
#                 {
#                     "name": "Poland",
#                     "value": 1
#                 },
#                 {
#                     "name": "Mexico",
#                     "value": 1
#                 },
#                 {
#                     "name": "Qatar",
#                     "value": 1
#                 },
#                 {
#                     "name": "Lebanon",
#                     "value": 1
#                 },
#                 {
#                     "name": "Ireland",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "45%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "outside",
#                 "margin": 8,
#                 "formatter": " {b|{b}: }{c}  {per|{d}%} ",
#                 "backgroundColor": "#eee",
#                 "borderColor": "#aaa",
#                 "borderWidth": 1,
#                 "borderRadius": 4,
#                 "rich": {
#                     "a": {
#                         "color": "#999",
#                         "lineHeight": 22,
#                         "align": "center"
#                     },
#                     "abg": {
#                         "backgroundColor": "#e3e3e3",
#                         "width": "100%",
#                         "align": "right",
#                         "height": 20,
#                         "borderRadius": [
#                             4,
#                             4,
#                             0,
#                             0
#                         ]
#                     },
#                     "hr": {
#                         "borderColor": "#aaa",
#                         "width": "100%",
#                         "borderWidth": 0.5,
#                         "height": 0
#                     },
#                     "b": {
#                         "fontSize": 10,
#                         "lineHeight": 18
#                     },
#                     "per": {
#                         "color": "#eee",
#                         "backgroundColor": "#334455",
#                         "padding": [
#                             2,
#                             4
#                         ],
#                         "borderRadius": 2
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "United States",
#                 "China",
#                 "United Kingdom",
#                 "Japan",
#                 "France",
#                 "Germany",
#                 "Korea",
#                 "Italy",
#                 "Canada",
#                 "Australia",
#                 "Swizetland",
#                 "New Zealand",
#                 "India",
#                 "Poland",
#                 "Mexico",
#                 "Qatar",
#                 "Lebanon",
#                 "Ireland"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "top250\u7535\u5f71\u5236\u7247\u56fd\u5bb6\u6bd4\u91cd",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_768c3ab23358468088668b5e7d440cf7.setOption(option_768c3ab23358468088668b5e7d440cf7);
#         });
#     </script>

# %%
# Bar - Bar_base
# https://gallery.pyecharts.org/#/Bar/bar_base
from pyecharts.globals import ThemeType
rating_attr = []
rating_value = []
p_lists = df['rating_people'].sort_values(ascending=False)

for i in range(20):
    rating_attr.append(df['film_name'][p_lists.index[i]])
    rating_value.append(int(p_lists[p_lists.index[i]]))

x_choose=rating_attr
y_values=rating_value

b2= (
    Bar(init_opts=opts.InitOpts(
        theme=ThemeType.DARK
    ))
    .add_xaxis(x_choose)
    .add_yaxis("评价人数", y_values)
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=30), name="电影"),
        title_opts=opts.TitleOpts(title="top250电影评价人数"),
        yaxis_opts=opts.AxisOpts(name="数量"),
    )
)
b2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1a7ff3ce77b0478b9f506541896a892e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1a7ff3ce77b0478b9f506541896a892e = echarts.init(
#                     document.getElementById('1a7ff3ce77b0478b9f506541896a892e'), 'dark', {renderer: 'canvas'});
#                 var option_1a7ff3ce77b0478b9f506541896a892e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u8bc4\u4ef7\u4eba\u6570",
#             "legendHoverLink": true,
#             "data": [
#                 2627015,
#                 2126026,
#                 2051542,
#                 1975120,
#                 1951139,
#                 1935585,
#                 1921776,
#                 1892645,
#                 1730974,
#                 1716904,
#                 1673057,
#                 1584478,
#                 1539773,
#                 1525252,
#                 1507282,
#                 1493002,
#                 1469793,
#                 1441453,
#                 1405713,
#                 1395382
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8bc4\u4ef7\u4eba\u6570"
#             ],
#             "selected": {
#                 "\u8bc4\u4ef7\u4eba\u6570": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "name": "\u7535\u5f71",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 30,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8096\u7533\u514b\u7684\u6551\u8d4e",
#                 "\u8fd9\u4e2a\u6740\u624b\u4e0d\u592a\u51b7",
#                 "\u5343\u4e0e\u5343\u5bfb",
#                 "\u963f\u7518\u6b63\u4f20",
#                 "\u9738\u738b\u522b\u59ec",
#                 "\u6cf0\u5766\u5c3c\u514b\u53f7",
#                 "\u6211\u4e0d\u662f\u836f\u795e",
#                 "\u76d7\u68a6\u7a7a\u95f4",
#                 "\u75af\u72c2\u52a8\u7269\u57ce",
#                 "\u4e09\u50bb\u5927\u95f9\u5b9d\u83b1\u575e",
#                 "\u6026\u7136\u5fc3\u52a8",
#                 "\u661f\u9645\u7a7f\u8d8a",
#                 "\u6d77\u4e0a\u94a2\u7434\u5e08",
#                 "\u8ba9\u5b50\u5f39\u98de",
#                 "\u695a\u95e8\u7684\u4e16\u754c",
#                 "\u5bfb\u68a6\u73af\u6e38\u8bb0",
#                 "\u7eff\u76ae\u4e66",
#                 "\u6454\u8de4\u5427\uff01\u7238\u7238",
#                 "\u5927\u8bdd\u897f\u6e38\u4e4b\u5927\u5723\u5a36\u4eb2",
#                 "\u5f53\u5e78\u798f\u6765\u6572\u95e8"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u6570\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "top250\u7535\u5f71\u8bc4\u4ef7\u4eba\u6570",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_1a7ff3ce77b0478b9f506541896a892e.setOption(option_1a7ff3ce77b0478b9f506541896a892e);
#         });
#     </script>

# %% [markdown]
# ## 视角二

# %%
# Pie - Customized_pie
# https://gallery.pyecharts.org/#/Pie/customized_pie

f_type_lists = []
for i in range(len(df['filmType'])):
    for j in range(len(df['filmType'][i].split(','))):
        f_type_lists.append(df['filmType'][i].split(',')[j].split("'")[1].split("'")[0])

# 去除元素中的空格和换行
f_type_lists = [x.strip() for x in f_type_lists if x.strip() != '']

df_f_type = pd.DataFrame(f_type_lists)
df_f_type.value_counts()
x_f_type_data = []
y_f_type_data = []
for i in range(len(df_f_type.value_counts())):
    x_f_type_data.append(df_f_type.value_counts().index[i][0])
    y_f_type_data.append(int(df_f_type.value_counts()[i]))
    data_pair = [list(z) for z in zip(x_f_type_data, y_f_type_data)]
data_pair.sort(key=lambda x: x[1])

p2=(
    Pie(
        init_opts=opts.InitOpts(
            theme=ThemeType.DARK
        ))
    .add(
        series_name="类型",
        data_pair=data_pair,
        rosetype="radius",
        radius="55%",
        center=["50%", "50%"],
        label_opts=opts.LabelOpts(is_show=False, position="center"),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="电影类型",
            pos_left="center",
            pos_top="20",
            title_textstyle_opts=opts.TextStyleOpts(color="#fff"),
        ),
        legend_opts=opts.LegendOpts(is_show=False),
    )
    .set_series_opts(
        tooltip_opts=opts.TooltipOpts(
            trigger="item", formatter="{a} <br/>{b}: {c} ({d}%)"
        ),
        label_opts=opts.LabelOpts(color="rgba(255, 255, 255, 0.3)"),
    )
)
p2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f4dea54b101b4b6ba0b375b1585677af" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f4dea54b101b4b6ba0b375b1585677af = echarts.init(
#                     document.getElementById('f4dea54b101b4b6ba0b375b1585677af'), 'dark', {renderer: 'canvas'});
#                 var option_f4dea54b101b4b6ba0b375b1585677af = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u7c7b\u578b",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u8fd0\u52a8",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u60c5\u8272",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u6050\u6016",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u707e\u96be",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u7eaa\u5f55\u7247",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u897f\u90e8",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u6b66\u4fa0",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u513f\u7ae5",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u6b4c\u821e",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u540c\u6027",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u5386\u53f2",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u97f3\u4e50",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u53e4\u88c5",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u6218\u4e89",
#                     "value": 15
#                 },
#                 {
#                     "name": "\u4f20\u8bb0",
#                     "value": 15
#                 },
#                 {
#                     "name": "\u5bb6\u5ead",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u79d1\u5e7b",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u60ac\u7591",
#                     "value": 29
#                 },
#                 {
#                     "name": "\u52a8\u4f5c",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u60ca\u609a",
#                     "value": 34
#                 },
#                 {
#                     "name": "\u52a8\u753b",
#                     "value": 37
#                 },
#                 {
#                     "name": "\u5947\u5e7b",
#                     "value": 41
#                 },
#                 {
#                     "name": "\u72af\u7f6a",
#                     "value": 42
#                 },
#                 {
#                     "name": "\u5192\u9669",
#                     "value": 46
#                 },
#                 {
#                     "name": "\u559c\u5267",
#                     "value": 54
#                 },
#                 {
#                     "name": "\u7231\u60c5",
#                     "value": 57
#                 },
#                 {
#                     "name": "\u5267\u60c5",
#                     "value": 188
#                 }
#             ],
#             "radius": "55%",
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "color": "rgba(255, 255, 255, 0.3)",
#                 "margin": 8
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "formatter": "{a} <br/>{b}: {c} ({d}%)",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8fd0\u52a8",
#                 "\u60c5\u8272",
#                 "\u6050\u6016",
#                 "\u707e\u96be",
#                 "\u7eaa\u5f55\u7247",
#                 "\u897f\u90e8",
#                 "\u6b66\u4fa0",
#                 "\u513f\u7ae5",
#                 "\u6b4c\u821e",
#                 "\u540c\u6027",
#                 "\u5386\u53f2",
#                 "\u97f3\u4e50",
#                 "\u53e4\u88c5",
#                 "\u6218\u4e89",
#                 "\u4f20\u8bb0",
#                 "\u5bb6\u5ead",
#                 "\u79d1\u5e7b",
#                 "\u60ac\u7591",
#                 "\u52a8\u4f5c",
#                 "\u60ca\u609a",
#                 "\u52a8\u753b",
#                 "\u5947\u5e7b",
#                 "\u72af\u7f6a",
#                 "\u5192\u9669",
#                 "\u559c\u5267",
#                 "\u7231\u60c5",
#                 "\u5267\u60c5"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u7535\u5f71\u7c7b\u578b",
#             "left": "center",
#             "top": "20",
#             "padding": 5,
#             "itemGap": 10,
#             "textStyle": {
#                 "color": "#fff"
#             }
#         }
#     ]
# };
#                 chart_f4dea54b101b4b6ba0b375b1585677af.setOption(option_f4dea54b101b4b6ba0b375b1585677af);
#         });
#     </script>

# %% [markdown]
# ## 视角三

# %%
# Line - Line_base
# https://gallery.pyecharts.org/#/Line/line_base

# 取出年份, 计数排序
releaseYear = pd.to_datetime(df['initialReleaseDate'])
releaseYear = pd.DatetimeIndex(releaseYear).year
releaseYear = releaseYear.value_counts().sort_index()

xais = []
yais = []
xais = releaseYear.index.tolist()
yais = releaseYear.values.tolist()

# xaxis只能识别字符串，将xais数组元素改为字符串类型
for i in range(len(xais)):
    xais[i] = str(xais[i])

l=(
    Line()
    .add_xaxis(xaxis_data=xais)
    .add_yaxis(
        series_name="",
        y_axis=yais,
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="top250电影年份"),
        )
)
l.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0381ccb07e6a4722bcb1f12fec1cbd3f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0381ccb07e6a4722bcb1f12fec1cbd3f = echarts.init(
#                     document.getElementById('0381ccb07e6a4722bcb1f12fec1cbd3f'), 'white', {renderer: 'canvas'});
#                 var option_0381ccb07e6a4722bcb1f12fec1cbd3f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "1931",
#                     1
#                 ],
#                 [
#                     "1936",
#                     1
#                 ],
#                 [
#                     "1939",
#                     1
#                 ],
#                 [
#                     "1940",
#                     1
#                 ],
#                 [
#                     "1950",
#                     1
#                 ],
#                 [
#                     "1952",
#                     1
#                 ],
#                 [
#                     "1953",
#                     1
#                 ],
#                 [
#                     "1954",
#                     1
#                 ],
#                 [
#                     "1957",
#                     2
#                 ],
#                 [
#                     "1960",
#                     1
#                 ],
#                 [
#                     "1961",
#                     1
#                 ],
#                 [
#                     "1965",
#                     1
#                 ],
#                 [
#                     "1966",
#                     1
#                 ],
#                 [
#                     "1968",
#                     1
#                 ],
#                 [
#                     "1972",
#                     1
#                 ],
#                 [
#                     "1974",
#                     1
#                 ],
#                 [
#                     "1975",
#                     1
#                 ],
#                 [
#                     "1979",
#                     1
#                 ],
#                 [
#                     "1982",
#                     1
#                 ],
#                 [
#                     "1984",
#                     2
#                 ],
#                 [
#                     "1986",
#                     2
#                 ],
#                 [
#                     "1987",
#                     3
#                 ],
#                 [
#                     "1988",
#                     4
#                 ],
#                 [
#                     "1989",
#                     2
#                 ],
#                 [
#                     "1990",
#                     3
#                 ],
#                 [
#                     "1991",
#                     5
#                 ],
#                 [
#                     "1992",
#                     2
#                 ],
#                 [
#                     "1993",
#                     7
#                 ],
#                 [
#                     "1994",
#                     13
#                 ],
#                 [
#                     "1995",
#                     7
#                 ],
#                 [
#                     "1996",
#                     1
#                 ],
#                 [
#                     "1997",
#                     8
#                 ],
#                 [
#                     "1998",
#                     4
#                 ],
#                 [
#                     "1999",
#                     6
#                 ],
#                 [
#                     "2000",
#                     5
#                 ],
#                 [
#                     "2001",
#                     9
#                 ],
#                 [
#                     "2002",
#                     8
#                 ],
#                 [
#                     "2003",
#                     10
#                 ],
#                 [
#                     "2004",
#                     13
#                 ],
#                 [
#                     "2005",
#                     4
#                 ],
#                 [
#                     "2006",
#                     9
#                 ],
#                 [
#                     "2007",
#                     4
#                 ],
#                 [
#                     "2008",
#                     10
#                 ],
#                 [
#                     "2009",
#                     9
#                 ],
#                 [
#                     "2010",
#                     13
#                 ],
#                 [
#                     "2011",
#                     8
#                 ],
#                 [
#                     "2012",
#                     5
#                 ],
#                 [
#                     "2013",
#                     11
#                 ],
#                 [
#                     "2014",
#                     9
#                 ],
#                 [
#                     "2015",
#                     10
#                 ],
#                 [
#                     "2016",
#                     10
#                 ],
#                 [
#                     "2017",
#                     5
#                 ],
#                 [
#                     "2018",
#                     6
#                 ],
#                 [
#                     "2019",
#                     2
#                 ],
#                 [
#                     "2020",
#                     1
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "o

# %% [markdown]
# ## 视角四

# %%
# Funnel - Funnel_base
# https://gallery.pyecharts.org/#/Funnel/funnel_base
actors = df['actor']
actors = pd.Series([str(line).strip('[').strip(']') for line in actors])
actors = actors.str.split(',', expand=True)

actors_index = pd.concat([actors.loc[0], actors.loc[1]], axis=0, ignore_index=True)
for i in range(2, len(actors)):
    actors_index = pd.concat([actors_index, actors.loc[i]], axis=0, ignore_index=True)
actors_index.dropna(inplace=True)
actors_index = actors_index.str.replace("'", "")
actors_sort = actors_index.value_counts().sort_values(ascending=False)

x_data = actors_sort.index.to_list()
y_data = actors_sort.values.tolist()

p_data = []
for index in range(30):
    p_ionfo=[x_data[index],y_data[index]]
    p_data.append(p_ionfo)
p_data
f = (
    Funnel()
    .add(
        "参演", 
        p_data, 
        label_opts=opts.LabelOpts(position="inside")
        )
    .set_global_opts(
        title_opts = opts.TitleOpts(title="top250电影参演人员"),
        legend_opts= opts.LegendOpts(is_show=False)
        )
    # .render("funnel_base.html")
)
f.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ab66855728014672b32bde0f0a46dccd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ab66855728014672b32bde0f0a46dccd = echarts.init(
#                     document.getElementById('ab66855728014672b32bde0f0a46dccd'), 'white', {renderer: 'canvas'});
#                 var option_ab66855728014672b32bde0f0a46dccd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u53c2\u6f14",
#             "data": [
#                 {
#                     "name": "  \u96e8\u679c\u00b7\u7ef4\u6587 ",
#                     "value": 7
#                 },
#                 {
#                     "name": "  \u827e\u4f26\u00b7\u745e\u514b\u66fc ",
#                     "value": 7
#                 },
#                 {
#                     "name": "  \u52a0\u91cc\u00b7\u5965\u5fb7\u66fc ",
#                     "value": 6
#                 },
#                 {
#                     "name": " \u5468\u661f\u9a70 ",
#                     "value": 6
#                 },
#                 {
#                     "name": "  \u739b\u5409\u00b7\u53f2\u5bc6\u65af ",
#                     "value": 5
#                 },
#                 {
#                     "name": " \u83b1\u6602\u7eb3\u591a\u00b7\u8fea\u5361\u666e\u91cc\u5965 ",
#                     "value": 5
#                 },
#                 {
#                     "name": " \u9a6c\u7279\u00b7\u8fbe\u8499 ",
#                     "value": 5
#                 },
#                 {
#                     "name": "  \u743c\u00b7\u827e\u4f26 ",
#                     "value": 5
#                 },
#                 {
#                     "name": "  \u9c81\u4f2f\u7279\u00b7\u683c\u6797\u7279 ",
#                     "value": 5
#                 },
#                 {
#                     "name": " \u4e39\u5c3c\u5c14\u00b7\u96f7\u5fb7\u514b\u91cc\u592b ",
#                     "value": 5
#                 },
#                 {
#                     "name": "  \u827e\u739b\u00b7\u6c83\u68ee ",
#                     "value": 5
#                 },
#                 {
#                     "name": "  \u6c64\u59c6\u00b7\u8d39\u5c14\u987f ",
#                     "value": 5
#                 },
#                 {
#                     "name": " \u5f20\u56fd\u8363 ",
#                     "value": 5
#                 },
#                 {
#                     "name": "  \u8fc8\u514b\u5c14\u00b7\u51ef\u6069 ",
#                     "value": 5
#                 },
#                 {
#                     "name": "  \u90a6\u59ae\u00b7\u6000\u7279 ",
#                     "value": 5
#                 },
#                 {
#                     "name": "  \u5f20\u66fc\u7389 ",
#                     "value": 5
#                 },
#                 {
#                     "name": "  \u5218\u5609\u73b2 ",
#                     "value": 5
#                 },
#                 {
#                     "name": " \u6c64\u59c6\u00b7\u6c49\u514b\u65af ",
#                     "value": 5
#                 },
#                 {
#                     "name": "  \u6731\u4e3d\u00b7\u6c83\u7279\u65af ",
#                     "value": 4
#                 },
#                 {
#                     "name": "  \u62c9\u5c14\u592b\u00b7\u8d39\u56e0\u65af ",
#                     "value": 4
#                 },
#                 {
#                     "name": "  \u5c71\u5bfa\u5b8f\u4e00 ",
#                     "value": 4
#                 },
#                 {
#                     "name": "  \u5434\u5b5f\u8fbe ",
#                     "value": 4
#                 },
#                 {
#                     "name": "  \u6881\u671d\u4f1f ",
#                     "value": 4
#                 },
#                 {
#                     "name": " \u4f0a\u6851\u00b7\u970d\u514b ",
#                     "value": 4
#                 },
#                 {
#                     "name": "  \u8096\u6069\u00b7\u5bbe ",
#                     "value": 4
#                 },
#                 {
#                     "name": "  \u90a6\u5c3c\u00b7\u4ea8\u7279 ",
#                     "value": 4
#                 },
#                 {
#                     "name": "  \u7ea6\u7ff0\u00b7\u62c9\u5c91\u8d1d\u683c ",
#                     "value": 4
#                 },
#                 {
#                     "name": "  \u5b89\u8fea\u00b7\u745f\u91d1\u65af ",
#                     "value": 4
#                 },
#                 {
#                     "name": "  \u6469\u6839\u00b7\u5f17\u91cc\u66fc ",
#                     "value": 4
#                 },
#                 {
#                     "name": "  \u5965\u5170\u591a\u00b7\u5e03\u9c81\u59c6 ",
#                     "value": 4
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "  \u827e\u739b\u00b7\u6c83\u68ee ",
#                 "  \u5218\u5609\u73b2 ",
#                 "  \u5965\u5170\u591a\u00b7\u5e03\u9c81\u59c6 ",
#                 "  \u52a0\u91cc\u00b7\u5965\u5fb7\u66fc ",
#                 "  \u6469\u6839\u00b7\u5f17\u91cc\u66fc ",
#                 "  \u96e8\u679c\u00b7\u7ef4\u6587 ",
#                 "  \u9c81\u4f2f\u7279\u00b7\u683c\u6797\u7279 ",
#                 "  \u62c9\u5c14\u592b\u00b7\u8d39\u56e0\u65af ",
#                 "  \u5f20\u66fc\u7389 ",
#                 "  \u5434\u5b5f\u8fbe ",
#                 "  \u7ea6\u7ff0\u00b7\u62c9\u5c91\u8d1d\u683c ",
#                 " \u5468\u661f\u9a70 ",
#                 " \u4f0a\u6851\u00b7\u970d\u514b ",
#                 "  \u743c\u00b7\u827e\u4f26 ",
#                 "  \u6c64\u59c6\u00b7\u8d39\u5c14\u987f ",
#                 "  \u90a6\u59ae\u00b7\u6000\u7279 ",
#                 "  \u739b\u5409\u00b7\u53f2\u5bc6\u65af ",
#                 " \u83b1\u6602\u7eb3\u591a\u00b7\u8fea\u5361\u666e\u91cc\u5965 ",
#                 "  \u827e\u4f26\u00b7\u745e\u514b\u66fc ",
#                 "  \u8096\u6069\u00b7\u5bbe ",
#                 "  \u6881\u671d\u4f1f ",
#                 "  \u5c71\u5bfa\u5b8f\u4e00 ",
#                 " \u6c64\u59c6\u00b7\u6c49\u514b\u65af ",
#                 " \u5f20\u56fd\u8363 ",
#                 "  \u5b89\u8fea\u00b7\u745f\u91d1\u65af ",
#                 " \u4e39\u5c3c\u5c14\u00b7\u96f7\u5fb7\u514b\u91cc\u592b ",
#                 "  \u8fc8\u514b\u5c14\u00b7\u51ef\u6069 ",
#                 "  \u6731\u4e3d\u00b7\u6c83\u7279\u65af ",
#                 " \u9a6c\u7279\u00b7\u8fbe\u8499 ",
#                 "  \u90a6\u5c3c\u00b7\u4ea8\u7279 "
#             ],
#             "selected": {
#                 "  \u96e8\u679c\u00b7\u7ef4\u6587 ": true,
#                 "  \u827e\u4f26\u00b7\u745e\u514b\u66fc ": true,
#                 "  \u52a0\u91cc\u00b7\u5965\u5fb7\u66fc ": true,
#                 " \u5468\u661f\u9a70 ": true,
#                 "  \u739b\u5409\u00b7\u53f2\u5bc6\u65af ": true,
#                 " \u83b1\u6602\u7eb3\u591a\u00b7\u8fea\u5361\u666e\u91cc\u5965 ": true,
#                 " \u9a6c\u7279\u00b7\u8fbe\u8499 ": true,
#                 "  \u743c\u00b7\u827e\u4f26 ": true,
#                 "  \u9c81\u4f2f\u7279\u00b7\u683c\u6797\u7279 ": true,
#                 " \u4e39\u
